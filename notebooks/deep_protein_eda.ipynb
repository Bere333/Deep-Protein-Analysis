# %% [markdown]
# # Install Dependencies

# %%
# !pip install biopython

# %%
# !pip install obonet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [obonet]x]
# ...

# %%
# !pip install biopython

# %%
# imports 
import pandas as pd
from Bio import SeqIO
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Verificamos si existe la carpeta que Kaggle crea por defecto
if os.path.exists('/kaggle/input'):
    BASE_DIR = "/kaggle/input/cafa-6-protein-function-prediction/Train"
    print("Ejecutando en la nube de Kaggle")
else:
    # Ruta en tu Mac (ajusta según donde guardaste los archivos)
    BASE_DIR = "../data/Train"
    print("Ejecutando localmente en mi Mac")
# Out:
# Ejecutando localmente en mi Mac

# %%
train_terms = pd.read_csv(f"{BASE_DIR}/train_terms.tsv", sep="\t")
fasta_file = f"{BASE_DIR}/train_sequences.fasta"
print("¡Archivo cargado con éxito!")
print(train_terms.head())
# Out:
# ¡Archivo cargado con éxito!
#   EntryID        term aspect
# 0  Q5W0B1  GO:0000785      C
# 1  Q5W0B1  GO:0004842      F
# 2  Q5W0B1  GO:0051865      P
# 3  Q5W0B1  GO:0006275      P
# 4  Q5W0B1  GO:0006513      P

# %%
print(fasta_file)
# Out:
# ../data/Train/train_sequences.fasta
